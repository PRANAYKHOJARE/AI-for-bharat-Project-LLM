# %% [markdown]
# # Quickstart Guide for Strands Agents
#
# Strands Agents is a powerful framework for building AI agents that can interact with AWS services and perform complex tasks. This quickstart guide will help you get started with creating your first Strands agent.
#
# ## Prerequisites
#
# - Python 3.10 or later
# - AWS account configured with appropriate permissions
# - Basic understanding of Python programming
#
# Lets get started !

# %%
# Install Strands using pip

# %pip install strands-agents strands-agents-tools

# %% [markdown]
# ## Creating Your First Agent
#
# Lets get an overview of the agentic components needed.
#
# ### 1. Create a simple Agent:
#
# This will create an agent with the default model provider, [Amazon Bedrock](https://aws.amazon.com/bedrock/), and the default model, Claude 3.7 Sonnet, in the region of your AWS setup. While the agent runs in the same local environment as it is being invoked, Amazon Bedrock models will run in an AWS account and your agent will invoke the model in the cloud account. The architecture looks as following:
#
# <div style="text-align:center">
#     <img src="images/simple_agent.png" width="75%" />
# </div>

# %%
from strands import Agent

# Initialize your agent
agent = Agent(
    system_prompt="You are a helpful assistant that provides concise responses."
)

# Send a message to the agent
response = agent("Hello! What can you do?")
print(response)
# Out:
# Hello! I'm Claude, an AI assistant. I can help you with a wide variety of tasks, including:
#
# - Answering questions and explaining topics
# - Writing and editing (essays, emails, stories, etc.)
# - Analysis and research assistance
# - Math and coding problems
# - Creative projects like brainstorming ideas
# - Having conversations on topics that interest you
#
# What would you like help with today?Hello! I'm Claude, an AI assistant. I can help you with a wide variety of tasks, including:
#
# - Answering questions and explaining topics
# - Writing and editing (essays, emails, stories, etc.)
# - Analysis and research assistance
# - Math and coding problems
# - Creative projects like brainstorming ideas
# - Having conversations on topics that interest you
#
# What would you like help with today?

# %%
from strands import Agent

agent = Agent(model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")
print(agent.model.config)
# Out:
# {'model_id': 'us.anthropic.claude-3-7-sonnet-20250219-v1:0', 'include_tool_result_status': 'auto'}

# %%
import boto3
from strands import Agent
from strands.models import BedrockModel

# Create a BedrockModel
bedrock_model = BedrockModel(
    model_id="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    region_name='us-west-2',
    temperature=0.3,
)

agent = Agent(model=bedrock_model)

# %%
from strands import Agent, tool
from duckduckgo_search import DDGS
from duckduckgo_search.exceptions import RatelimitException, DuckDuckGoSearchException
import logging

# Configure logging
logging.getLogger("strands").setLevel(logging.INFO)

# Define a websearch tool
@tool
def websearch(keywords: str, region: str = "us-en", max_results: int | None = None) -> str:
    """Search the web to get updated information.
    Args:
        keywords (str): The search query keywords.
        region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc..
        max_results (int | None): The maximum number of results to return.
    Returns:
        List of dictionaries with search results.
    """
    try:
        results = DDGS().text(keywords, region=region, max_results=max_results)
        return results if results else "No results found."
    except RatelimitException:
        return "RatelimitException: Please try again after a short delay."
    except DuckDuckGoSearchException as d:
        return f"DuckDuckGoSearchException: {d}"
    except Exception as e:
        return f"Exception: {e}"

# Create a recipe assistant agent
recipe_agent = Agent(
    system_prompt="""You are RecipeBot, a helpful cooking assistant.
    Help users find recipes based on ingredients and answer cooking questions.
    Use the websearch tool to find recipes when users mention ingredients or to look up cooking information.""",
    tools=[websearch], # Import the websearch tool we created above
)

response = recipe_agent("Suggest a recipe with chicken and broccoli.")

print(f"Metrics : {response.metrics}") # Optional, but recommended.
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[11], line 38
#      30 # Create a recipe assistant agent
#      31 recipe_agent = Agent(
#      32     system_prompt="""You are RecipeBot, a helpful cooking assistant.
#      33     Help users find recipes based on ingredients and answer cooking questions.
#      34     Use the websearch tool to find recipes when users mention ingredients or to look up cooking information.""",
#      35     tools=[websearch], # Import the websearch tool we created above
#      36 )
# ---> 38 response = recipe_agent("Suggest a recipe with chicken and broccoli.")
#      40 print(f"Metrics : {response.metrics}") # Optional, but recommended.
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:349, in Agent.__call__(self, prompt, invocation_state, structured_output_model, **kwargs)
#     314 def __call__(
#     315     self,
#     316     prompt: AgentInput = None,
#    (...)    320     **kwargs: Any,
#     321 ) -> AgentResult:
#     322     """Process a natural language prompt through the agent's event loop.
#     323
#     324     This method implements the conversational interface with multiple input patterns:
#    (...)    347             - structured_output: Parsed structured output when structured_output_model was specified
#     348     """
# --> 349     return run_async(
#     350         lambda: self.invoke_async(
#     351             prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     352         )
#     353     )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:33, in run_async(async_func)
#      31 context = contextvars.copy_context()
#      32 future = executor.submit(context.run, execute)
# ---> 33 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:28, in run_async.<locals>.execute()
#      27 def execute() -> T:
# ---> 28     return asyncio.run(execute_async())
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:204, in run(main, debug, loop_factory)
#     200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 204     return runner.run(main)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:127, in Runner.run(self, coro, context)
#     125 self._interrupt_count = 0
#     126 try:
# --> 127     return self._loop.run_until_complete(task)
#     128 except exceptions.CancelledError:
#     129     if self._interrupt_count > 0:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py:719, in BaseEventLoop.run_until_complete(self, future)
#     716 if not future.done():
#     717     raise RuntimeError('Event loop stopped before Future completed.')
# --> 719 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:25, in run_async.<locals>.execute_async()
#      24 async def execute_async() -> T:
# ---> 25     return await async_func()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:392, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     363 """Process a natural language prompt through the agent's event loop.
#     364
#     365 This method implements the conversational interface with multiple input patterns:
#    (...)    387         - state: The final state of the event loop
#     388 """
#     389 events = self.stream_async(
#     390     prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     391 )
# --> 392 async for event in events:
#     393     _ = event
#     395 return cast(AgentResult, event["result"])
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:588, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     585 try:
#     586     events = self._run_loop(messages, merged_state, structured_output_model)
# --> 588     async for event in events:
#     589         event.prepare(invocation_state=merged_state)
#     591         if event.is_callback_event:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:636, in Agent._run_loop(self, messages, invocation_state, structured_output_model)
#     634 # Execute the event loop cycle with retry logic for context limits
#     635 events = self._execute_event_loop_cycle(invocation_state, structured_output_context)
# --> 636 async for event in events:
#     637     # Signal from the model provider that the message sent by the user should be redacted,
#     638     # likely due to a guardrail.
#     639     if (
#     640         isinstance(event, ModelStreamChunkEvent)
#     641         and event.chunk
#     642         and event.chunk.get("redactContent")
#     643         and event.chunk["redactContent"].get("redactUserContentMessage")
#     644     ):
#     645         self.messages[-1]["content"] = self._redact_user_content(
#     646             self.messages[-1]["content"], str(event.chunk["redactContent"]["redactUserContentMessage"])
#     647         )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:688, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context)
#     682 try:
#     683     events = event_loop_cycle(
#     684         agent=self,
#     685         invocation_state=invocation_state,
#     686         structured_output_context=structured_output_context,
#     687     )
# --> 688     async for event in events:
#     689         yield event
#     691 except ContextWindowOverflowException as e:
#     692     # Try reducing the context size and retrying
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:155, in event_loop_cycle(agent, invocation_state, structured_output_context)
#     151 else:
#     152     model_events = _handle_model_execution(
#     153         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     154     )
# --> 155     async for model_event in model_events:
#     156         if not isinstance(model_event, ModelStopReason):
#     157             yield model_event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:400, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     398                 yield EventLoopThrottleEvent(delay=current_delay)
#     399             else:
# --> 400                 raise e
#     402 try:
#     403     # Add message in trace and mark the end of the stream messages trace
#     404     stream_trace.add_message(message)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:341, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     339     tool_specs = agent.tool_registry.get_all_tool_specs()
#     340 try:
# --> 341     async for event in stream_messages(
#     342         agent.model,
#     343         agent.system_prompt,
#     344         agent.messages,
#     345         tool_specs,
#     346         system_prompt_content=agent._system_prompt_content,
#     347         tool_choice=structured_output_context.tool_choice,
#     348     ):
#     349         yield event
#     351     stop_reason, message, usage, metrics = event["stop"]
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:457, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, **kwargs)
#     447 start_time = time.time()
#     449 chunks = model.stream(
#     450     messages,
#     451     tool_specs if tool_specs else None,
#    (...)    454     system_prompt_content=system_prompt_content,
#     455 )
# --> 457 async for event in process_stream(chunks, start_time):
#     458     yield event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:391, in process_stream(chunks, start_time)
#     388 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     389 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 391 async for chunk in chunks:
#     392     # Track first byte time when we get first content
#     393     if first_byte_time is None and ("contentBlockDelta" in chunk or "contentBlockStart" in chunk):
#     394         first_byte_time = time.time()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:647, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#     643         break
#     645     yield event
# --> 647 await task
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:768, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     758     if (
#     759         e.response["Error"]["Code"] == "ValidationException"
#     760         and "with on-demand throughput isn’t supported" in error_message
#     761     ):
#     762         add_exception_note(
#     763             e,
#     764             "└ For more information see "
#     765             "https://strandsagents.com/latest/user-guide/concepts/model-providers/amazon-bedrock/#on-demand-throughput-isnt-supported",
#     766         )
# --> 768     raise e
#     770 finally:
#     771     callback()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:683, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     681 logger.debug("got response from model")
#     682 if streaming:
# --> 683     response = self.client.converse_stream(**request)
#     684     # Track tool use events to fix stopReason for streaming responses
#     685     has_tool_use = False
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the ConverseStream operation: Model use case details have not been submitted for this account. Fill out the Anthropic use case details form before using the model. If you have already filled out the form, try again in 15 minutes.
# └ Bedrock region: ap-south-1
# └ Model id: apac.anthropic.claude-sonnet-4-20250514-v1:0

# %%
from strands.models.ollama import OllamaModel

# Configure the Ollama model
ollama_model = OllamaModel(
    model_id="llama3.2:latest", # Make sure this is the model you downloaded from Ollama
    host="http://localhost:11434",
    params={
        "max_tokens": 2048,  # Adjust based on your model's capabilities
        "temperature": 0.7,  # Lower for more deterministic responses, higher for more creative
        "top_p": 0.9,        # Nucleus sampling parameter
        "stream": True,      # Enable streaming responses
    },
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from strands.models.ollama import OllamaModel
#       3 # Configure the Ollama model
#       4 ollama_model = OllamaModel(
#       5     model_id="llama3.2:latest", # Make sure this is the model you downloaded from Ollama
#       6     host="http://localhost:11434",
#    (...)     12     },
#      13 )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\ollama.py:10
#       7 import logging
#       8 from typing import Any, AsyncGenerator, Optional, Type, TypeVar, Union, cast
# ---> 10 import ollama
#      11 from pydantic import BaseModel
#      12 from typing_extensions import TypedDict, Unpack, override
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# Create the agent with tools
local_agent = Agent(
    system_prompt=system_prompt, # Define a system Prompt
    model=ollama_model,
    tools=[file_read, file_write, list_directory],  # Add your custom tools here
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Create the agent with tools
#       2 local_agent = Agent(
# ----> 3     system_prompt=system_prompt, # Define a system Prompt
#       4     model=ollama_model,
#       5     tools=[file_read, file_write, list_directory],  # Add your custom tools here
#       6 )
#
# NameError: name 'system_prompt' is not defined

# %%
# %pip install duckduckgo-search
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from strands import Agent, tool
from strands_tools import calculator

@tool
def weather():
    """ Get weather """ # Dummy implementation
    return "sunny"

agent = Agent(
    tools=[calculator, weather],
    system_prompt="You're a helpful assistant. You can do simple math calculation, and tell the weather.")

response = agent("What is the weather today?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[3], line 13
#       7     return "sunny"
#       9 agent = Agent(
#      10     tools=[calculator, weather],
#      11     system_prompt="You're a helpful assistant. You can do simple math calculation, and tell the weather.")
# ---> 13 response = agent("What is the weather today?")
#      15 print(response)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:349, in Agent.__call__(self, prompt, invocation_state, structured_output_model, **kwargs)
#     314 def __call__(
#     315     self,
#     316     prompt: AgentInput = None,
#    (...)    320     **kwargs: Any,
#     321 ) -> AgentResult:
#     322     """Process a natural language prompt through the agent's event loop.
#     323
#     324     This method implements the conversational interface with multiple input patterns:
#    (...)    347             - structured_output: Parsed structured output when structured_output_model was specified
#     348     """
# --> 349     return run_async(
#     350         lambda: self.invoke_async(
#     351             prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     352         )
#     353     )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:33, in run_async(async_func)
#      31 context = contextvars.copy_context()
#      32 future = executor.submit(context.run, execute)
# ---> 33 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:28, in run_async.<locals>.execute()
#      27 def execute() -> T:
# ---> 28     return asyncio.run(execute_async())
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:204, in run(main, debug, loop_factory)
#     200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 204     return runner.run(main)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:127, in Runner.run(self, coro, context)
#     125 self._interrupt_count = 0
#     126 try:
# --> 127     return self._loop.run_until_complete(task)
#     128 except exceptions.CancelledError:
#     129     if self._interrupt_count > 0:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py:719, in BaseEventLoop.run_until_complete(self, future)
#     716 if not future.done():
#     717     raise RuntimeError('Event loop stopped before Future completed.')
# --> 719 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:25, in run_async.<locals>.execute_async()
#      24 async def execute_async() -> T:
# ---> 25     return await async_func()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:392, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     363 """Process a natural language prompt through the agent's event loop.
#     364
#     365 This method implements the conversational interface with multiple input patterns:
#    (...)    387         - state: The final state of the event loop
#     388 """
#     389 events = self.stream_async(
#     390     prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     391 )
# --> 392 async for event in events:
#     393     _ = event
#     395 return cast(AgentResult, event["result"])
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:588, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     585 try:
#     586     events = self._run_loop(messages, merged_state, structured_output_model)
# --> 588     async for event in events:
#     589         event.prepare(invocation_state=merged_state)
#     591         if event.is_callback_event:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:636, in Agent._run_loop(self, messages, invocation_state, structured_output_model)
#     634 # Execute the event loop cycle with retry logic for context limits
#     635 events = self._execute_event_loop_cycle(invocation_state, structured_output_context)
# --> 636 async for event in events:
#     637     # Signal from the model provider that the message sent by the user should be redacted,
#     638     # likely due to a guardrail.
#     639     if (
#     640         isinstance(event, ModelStreamChunkEvent)
#     641         and event.chunk
#     642         and event.chunk.get("redactContent")
#     643         and event.chunk["redactContent"].get("redactUserContentMessage")
#     644     ):
#     645         self.messages[-1]["content"] = self._redact_user_content(
#     646             self.messages[-1]["content"], str(event.chunk["redactContent"]["redactUserContentMessage"])
#     647         )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:688, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context)
#     682 try:
#     683     events = event_loop_cycle(
#     684         agent=self,
#     685         invocation_state=invocation_state,
#     686         structured_output_context=structured_output_context,
#     687     )
# --> 688     async for event in events:
#     689         yield event
#     691 except ContextWindowOverflowException as e:
#     692     # Try reducing the context size and retrying
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:155, in event_loop_cycle(agent, invocation_state, structured_output_context)
#     151 else:
#     152     model_events = _handle_model_execution(
#     153         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     154     )
# --> 155     async for model_event in model_events:
#     156         if not isinstance(model_event, ModelStopReason):
#     157             yield model_event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:400, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     398                 yield EventLoopThrottleEvent(delay=current_delay)
#     399             else:
# --> 400                 raise e
#     402 try:
#     403     # Add message in trace and mark the end of the stream messages trace
#     404     stream_trace.add_message(message)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:341, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     339     tool_specs = agent.tool_registry.get_all_tool_specs()
#     340 try:
# --> 341     async for event in stream_messages(
#     342         agent.model,
#     343         agent.system_prompt,
#     344         agent.messages,
#     345         tool_specs,
#     346         system_prompt_content=agent._system_prompt_content,
#     347         tool_choice=structured_output_context.tool_choice,
#     348     ):
#     349         yield event
#     351     stop_reason, message, usage, metrics = event["stop"]
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:457, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, **kwargs)
#     447 start_time = time.time()
#     449 chunks = model.stream(
#     450     messages,
#     451     tool_specs if tool_specs else None,
#    (...)    454     system_prompt_content=system_prompt_content,
#     455 )
# --> 457 async for event in process_stream(chunks, start_time):
#     458     yield event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:391, in process_stream(chunks, start_time)
#     388 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     389 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 391 async for chunk in chunks:
#     392     # Track first byte time when we get first content
#     393     if first_byte_time is None and ("contentBlockDelta" in chunk or "contentBlockStart" in chunk):
#     394         first_byte_time = time.time()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:647, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#     643         break
#     645     yield event
# --> 647 await task
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:768, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     758     if (
#     759         e.response["Error"]["Code"] == "ValidationException"
#     760         and "with on-demand throughput isn’t supported" in error_message
#     761     ):
#     762         add_exception_note(
#     763             e,
#     764             "└ For more information see "
#     765             "https://strandsagents.com/latest/user-guide/concepts/model-providers/amazon-bedrock/#on-demand-throughput-isnt-supported",
#     766         )
# --> 768     raise e
#     770 finally:
#     771     callback()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:683, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     681 logger.debug("got response from model")
#     682 if streaming:
# --> 683     response = self.client.converse_stream(**request)
#     684     # Track tool use events to fix stopReason for streaming responses
#     685     has_tool_use = False
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the ConverseStream operation: Model use case details have not been submitted for this account. Fill out the Anthropic use case details form before using the model. If you have already filled out the form, try again in 15 minutes.
# └ Bedrock region: ap-south-1
# └ Model id: apac.anthropic.claude-sonnet-4-20250514-v1:0

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r"datetime.datetime.utcnow") 

from strands import Agent
# Initialize your agent
agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
    system_prompt="You are a helpful assistant that provides concise responses."
)

# Send a message to the agent
response = agent("Hello! Tell me a joke.")

# %% [markdown]
# ### 2. Add Tools to the Agent:
#
# The [strands-agents-tools](https://github.com/strands-agents/tools) repository provides some in-built tools which you can import. You can also create custom tools using the `@tool` decorator. We can create agents with built-in and custom tools. For instance, adding the built-in tool of a calculator and a custom tool for getting the weather you get the following architecture:
# <div style="text-align:center">
#     <img src="images/agent_with_tools.png" width="75%" />
# </div>
#
# Implementing this architecture you have the following:

# %%
from strands import Agent, tool
from strands_tools import calculator # Import the calculator tool

# Create a custom tool 
@tool
def weather():
    """ Get weather """ # Dummy implementation
    return "sunny"

agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
    tools=[calculator, weather],
    system_prompt="You're a helpful assistant. You can do simple math calculation, and tell the weather.")

response = agent("What is the weather today?")
print(response)

# %% [markdown]
# ### Invoking tool directly
#
# For some applications it is important to directly call the tool. For instance, you might want to debug the tool, pre-populate the agent knowledge with your customer's information or using a tool inside of another tool. In Strands you can do it using the ``tool`` method of your agent followed by the tool name

# %%
# Alternatively, you can invoke the tool directly like so:
agent.tool.calculator(expression="sin(x)", mode="derive", wrt="x", order=2)

# %% [markdown]
# ### 3. Changing the log level and format:
#
# Strands SDK uses Python's standard `logging` module to provide visibility into its operations.
#
# The Strands Agents SDK implements a straightforward logging approach:
#
# 1. **Module-level Loggers**: Each module in the SDK creates its own logger using logging.getLogger(__name__), following Python best practices for hierarchical logging.
# 2. **Root Logger**: All loggers in the SDK are children of the "strands" root logger, making it easy to configure logging for the entire SDK.
# 3. **Default Behavior**: By default, the SDK doesn't configure any handlers or log levels, allowing you to integrate it with your application's logging configuration.
#
# To enable logging for the Strands Agents SDK, you can configure the **"strands"** logger. If you want to change the log level, for example during debugging, or modify the log format, you can set the logger configuration as follows:

# %%
import logging
from strands import Agent

# Enables Strands debug log level
logging.getLogger("strands").setLevel(logging.DEBUG) # or logging.INFO

# Sets the logging format and streams logs to stderr
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s",
    handlers=[logging.StreamHandler()]
)

agent = Agent(model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")  # Optional: Specify the model ID
agent("Hello!")

# %% [markdown]
# ### 4. Model Provider
#
# The default model provider is [Amazon Bedrock](https://aws.amazon.com/bedrock/) and the default model is Claude 3.7 Sonnet in the region of your current AWS environment
#
# You can specify a different model in Amazon Bedrock providing the model ID string directly:

# %%
from strands import Agent

agent = Agent(model="anthropic.claude-3-5-haiku-20241022-v1:0")
print(agent.model.config)

# %% [markdown]
# For more control over the model configuration, you can create a `BedrockModel` provider instance:

# %%
import boto3
from strands import Agent
from strands.models import BedrockModel

# Create a BedrockModel
bedrock_model = BedrockModel(
    model_id="anthropic.claude-3-5-haiku-20241022-v1:0",
    region_name='us-west-2',
    temperature=0.3,
)

agent = Agent(model=bedrock_model)

# %% [markdown]
# More details on the available model providers on the [Model Provider Quickstart page](https://strandsagents.com/0.1.x/user-guide/quickstart/#model-providers)

# %% [markdown]
# **Congratulations !! Now you have learned how to build a simple agent using Strands!!**

# %% [markdown]
# ## [Optional] Lets Build a Task-Specific Agent - RecipeBot 🍽️
#
# Lets create a practical example of a task-specific agent. We create a `RecipeBot` that recommends recipes and answers any cooking related questions. Lets dive in !!
#
# Here's what we will create :

# %% [markdown]
# <div style="text-align:center">
#     <img src="images/interactive_recipe_agent.png" width="75%" />
# </div>

# %%
# Install the required packages# Also install strands-agents strands-agents-tools if you haven't already

# %%
from strands import Agent, tool
from ddgs import DDGS
from ddgs.exceptions import RatelimitException, DDGSException
import logging

# Configure logging
logging.getLogger("strands").setLevel(logging.INFO)

# Define a websearch tool
@tool
def websearch(keywords: str, region: str = "us-en", max_results: int | None = None) -> str:
    """Search the web to get updated information.
    Args:
        keywords (str): The search query keywords.
        region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc..
        max_results (int | None): The maximum number of results to return.
    Returns:
        List of dictionaries with search results.
    """
    try:
        results = DDGS().text(keywords, region=region, max_results=max_results)
        return results if results else "No results found."
    except RatelimitException:
        return "RatelimitException: Please try again after a short delay."
    except DDGSException as d:
        return f"DuckDuckGoSearchException: {d}"
    except Exception as e:
        return f"Exception: {e}"

# %%
# Create a recipe assistant agent
recipe_agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
    system_prompt="""You are RecipeBot, a helpful cooking assistant.
    Help users find recipes based on ingredients and answer cooking questions.
    Use the websearch tool to find recipes when users mention ingredients or to
    look up cooking information.""",
    # Import the websearch tool we created above
    tools=[websearch],
)

# %%
response = recipe_agent("Suggest a recipe with chicken and broccoli.")

# Other examples:
# response = recipe_agent("How do I cook quinoa?")
# response = recipe_agent("How can I substitute white wine in shrimp pasta?")
# response = recipe_agent("What are the health benefits of asparagus?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundException                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 response = recipe_agent("Suggest a recipe with chicken and broccoli.")
#       3 # Other examples:
#       4 # response = recipe_agent("How do I cook quinoa?")
#       5 # response = recipe_agent("How can I substitute white wine in shrimp pasta?")
#       6 # response = recipe_agent("What are the health benefits of asparagus?")
#       7 print(response)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:349, in Agent.__call__(self, prompt, invocation_state, structured_output_model, **kwargs)
#     314 def __call__(
#     315     self,
#     316     prompt: AgentInput = None,
#    (...)    320     **kwargs: Any,
#     321 ) -> AgentResult:
#     322     """Process a natural language prompt through the agent's event loop.
#     323
#     324     This method implements the conversational interface with multiple input patterns:
#    (...)    347             - structured_output: Parsed structured output when structured_output_model was specified
#     348     """
# --> 349     return run_async(
#     350         lambda: self.invoke_async(
#     351             prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     352         )
#     353     )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:33, in run_async(async_func)
#      31 context = contextvars.copy_context()
#      32 future = executor.submit(context.run, execute)
# ---> 33 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:28, in run_async.<locals>.execute()
#      27 def execute() -> T:
# ---> 28     return asyncio.run(execute_async())
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:204, in run(main, debug, loop_factory)
#     200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
#     203 with Runner(debug=debug, loop_factory=loop_factory) as runner:
# --> 204     return runner.run(main)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\runners.py:127, in Runner.run(self, coro, context)
#     125 self._interrupt_count = 0
#     126 try:
# --> 127     return self._loop.run_until_complete(task)
#     128 except exceptions.CancelledError:
#     129     if self._interrupt_count > 0:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\base_events.py:719, in BaseEventLoop.run_until_complete(self, future)
#     716 if not future.done():
#     717     raise RuntimeError('Event loop stopped before Future completed.')
# --> 719 return future.result()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\_async.py:25, in run_async.<locals>.execute_async()
#      24 async def execute_async() -> T:
# ---> 25     return await async_func()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:392, in Agent.invoke_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     363 """Process a natural language prompt through the agent's event loop.
#     364
#     365 This method implements the conversational interface with multiple input patterns:
#    (...)    387         - state: The final state of the event loop
#     388 """
#     389 events = self.stream_async(
#     390     prompt, invocation_state=invocation_state, structured_output_model=structured_output_model, **kwargs
#     391 )
# --> 392 async for event in events:
#     393     _ = event
#     395 return cast(AgentResult, event["result"])
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:588, in Agent.stream_async(self, prompt, invocation_state, structured_output_model, **kwargs)
#     585 try:
#     586     events = self._run_loop(messages, merged_state, structured_output_model)
# --> 588     async for event in events:
#     589         event.prepare(invocation_state=merged_state)
#     591         if event.is_callback_event:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:636, in Agent._run_loop(self, messages, invocation_state, structured_output_model)
#     634 # Execute the event loop cycle with retry logic for context limits
#     635 events = self._execute_event_loop_cycle(invocation_state, structured_output_context)
# --> 636 async for event in events:
#     637     # Signal from the model provider that the message sent by the user should be redacted,
#     638     # likely due to a guardrail.
#     639     if (
#     640         isinstance(event, ModelStreamChunkEvent)
#     641         and event.chunk
#     642         and event.chunk.get("redactContent")
#     643         and event.chunk["redactContent"].get("redactUserContentMessage")
#     644     ):
#     645         self.messages[-1]["content"] = self._redact_user_content(
#     646             self.messages[-1]["content"], str(event.chunk["redactContent"]["redactUserContentMessage"])
#     647         )
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\agent\agent.py:688, in Agent._execute_event_loop_cycle(self, invocation_state, structured_output_context)
#     682 try:
#     683     events = event_loop_cycle(
#     684         agent=self,
#     685         invocation_state=invocation_state,
#     686         structured_output_context=structured_output_context,
#     687     )
# --> 688     async for event in events:
#     689         yield event
#     691 except ContextWindowOverflowException as e:
#     692     # Try reducing the context size and retrying
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:155, in event_loop_cycle(agent, invocation_state, structured_output_context)
#     151 else:
#     152     model_events = _handle_model_execution(
#     153         agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context
#     154     )
# --> 155     async for model_event in model_events:
#     156         if not isinstance(model_event, ModelStopReason):
#     157             yield model_event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:400, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     398                 yield EventLoopThrottleEvent(delay=current_delay)
#     399             else:
# --> 400                 raise e
#     402 try:
#     403     # Add message in trace and mark the end of the stream messages trace
#     404     stream_trace.add_message(message)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\event_loop.py:341, in _handle_model_execution(agent, cycle_span, cycle_trace, invocation_state, tracer, structured_output_context)
#     339     tool_specs = agent.tool_registry.get_all_tool_specs()
#     340 try:
# --> 341     async for event in stream_messages(
#     342         agent.model,
#     343         agent.system_prompt,
#     344         agent.messages,
#     345         tool_specs,
#     346         system_prompt_content=agent._system_prompt_content,
#     347         tool_choice=structured_output_context.tool_choice,
#     348     ):
#     349         yield event
#     351     stop_reason, message, usage, metrics = event["stop"]
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:457, in stream_messages(model, system_prompt, messages, tool_specs, tool_choice, system_prompt_content, **kwargs)
#     447 start_time = time.time()
#     449 chunks = model.stream(
#     450     messages,
#     451     tool_specs if tool_specs else None,
#    (...)    454     system_prompt_content=system_prompt_content,
#     455 )
# --> 457 async for event in process_stream(chunks, start_time):
#     458     yield event
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\event_loop\streaming.py:391, in process_stream(chunks, start_time)
#     388 usage: Usage = Usage(inputTokens=0, outputTokens=0, totalTokens=0)
#     389 metrics: Metrics = Metrics(latencyMs=0, timeToFirstByteMs=0)
# --> 391 async for chunk in chunks:
#     392     # Track first byte time when we get first content
#     393     if first_byte_time is None and ("contentBlockDelta" in chunk or "contentBlockStart" in chunk):
#     394         first_byte_time = time.time()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:647, in BedrockModel.stream(self, messages, tool_specs, system_prompt, tool_choice, system_prompt_content, **kwargs)
#     643         break
#     645     yield event
# --> 647 await task
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\opentelemetry\instrumentation\threading\__init__.py:171, in ThreadingInstrumentor.__wrap_thread_pool_submit.<locals>.wrapped_func(*func_args, **func_kwargs)
#     169 try:
#     170     token = context.attach(otel_context)
# --> 171     return original_func(*func_args, **func_kwargs)
#     172 finally:
#     173     if token is not None:
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:768, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     758     if (
#     759         e.response["Error"]["Code"] == "ValidationException"
#     760         and "with on-demand throughput isn’t supported" in error_message
#     761     ):
#     762         add_exception_note(
#     763             e,
#     764             "└ For more information see "
#     765             "https://strandsagents.com/latest/user-guide/concepts/model-providers/amazon-bedrock/#on-demand-throughput-isnt-supported",
#     766         )
# --> 768     raise e
#     770 finally:
#     771     callback()
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\strands\models\bedrock.py:683, in BedrockModel._stream(self, callback, messages, tool_specs, system_prompt_content, tool_choice)
#     681 logger.debug("got response from model")
#     682 if streaming:
# --> 683     response = self.client.converse_stream(**request)
#     684     # Track tool use events to fix stopReason for streaming responses
#     685     has_tool_use = False
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\TEJAS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\botocore\client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# ResourceNotFoundException: An error occurred (ResourceNotFoundException) when calling the ConverseStream operation: Model use case details have not been submitted for this account. Fill out the Anthropic use case details form before using the model. If you have already filled out the form, try again in 15 minutes.
# └ Bedrock region: ap-south-1
# └ Model id: apac.anthropic.claude-sonnet-4-20250514-v1:0

# %% [markdown]
# #### And that's it! We now have a running usecase agent with tools in just a few lines of code 🥳.
#
# For more detailed quickstart guide, check out the [Strands documentation](https://strandsagents.com/0.1.x/user-guide/quickstart/).

# %% [markdown]
# ### [Optional] Run RecipeBot via CLI:
# you can run the agent in interactive mode via the command line (for instance using the terminal on SageMaker Studio) through the python script provided in `02_simple_interactive_usecase/recipe_bot.py`. This allows you to interact with the agent in a more dynamic way, sending messages and receiving responses via the CLI.
# Run these commands on a command line interface to run the agent in interactive mode:
#
# ```cli
# cd samples/01-tutorials/01-fundamentals/01-first-agent/02-simple-interactive-usecase/
# pip install -r requirements.txt
# python recipe_bot.py
# ```
#
# With this, you can talk to the bot via a command line interface(CLI).
